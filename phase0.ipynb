# %%
from pathlib import Path
import pandas as pd
import os

def describe_directory(base_path, preview_limit=0):
    base_path = Path(base_path).resolve()
    print(f"🔍 Scanning: {base_path}\n")

    all_files = sorted(base_path.rglob("*"))
    file_data = []

    for f in all_files:
        if f.is_file():
            size_kb = f.stat().st_size / 1024
            rel_path = f.relative_to(base_path)
            file_data.append({
                "Path": str(rel_path),
                "Size (KB)": round(size_kb, 2),
                "Extension": f.suffix.lower()
            })
    
    df = pd.DataFrame(file_data)
    if df.empty:
        print("🚫 No files found.")
    else:
        display(df)

    # Optional preview of CSV/XLSX files
    if preview_limit > 0:
        for file in df[df['Extension'].isin(['.csv', '.xlsx'])]['Path']:
            abs_path = base_path / file
            print(f"\n📄 Preview: {file}")
            try:
                if file.endswith('.csv'):
                    preview = pd.read_csv(abs_path, nrows=preview_limit)
                elif file.endswith('.xlsx'):
                    preview = pd.read_excel(abs_path, nrows=preview_limit)
                display(preview)
            except Exception as e:
                print(f"⚠️ Could not preview: {e}")

# Run it on your full project directory (not just /data)
describe_directory(BASE_DIR, preview_limit=5)
# Out:
# 🔍 Scanning: /home/rohit/Desktop/Projects/C-Elegans
#                                                   Path  Size (KB) Extension
# 0                            CElegansNeuroML/.git/HEAD       0.02
# 1                          CElegansNeuroML/.git/config       0.30
# 2                     CElegansNeuroML/.git/description       0.07
# 3     CElegansNeuroML/.git/hooks/applypatch-msg.sample       0.47   .sample
# 4         CElegansNeuroML/.git/hooks/commit-msg.sample       0.88   .sample
# ...                                                ...        ...       ...
# 3214                             file_index_master.csv     631.59      .csv
# 3215                                  merged_edges.csv    1420.74      .csv
# 3216                 merged_edges_with_relatedness.csv    1555.43      .csv
# 3217                          merged_lineage_table.csv     575.13      .csv
# 3218                                      phase0.ipynb       0.00    .ipynb
#
# [3219 rows x 3 columns]
# 📄 Preview: c302/c302/NeuronConnectFormatted.xlsx
#   Neuron 1 Neuron 2 Type  Nbr
# 0     ADAL     ADAR   EJ    1
# 1     ADAL     ADEL   Rp    1
# 2     ADAL     ADFL   Rp    1
# 3     ADAL     ADFL   EJ    1
# 4     ADAL     AIAL   Rp    1
# 📄 Preview: c302/c302/data/Bentley_et_al_2016_expression.csv
#   Entity1      Relationship   Entity2               Evidence  \
# 0    ADAL      Neuropeptide     PDF-1   Janssen et al., 2008
# 1    ADAR      Neuropeptide     PDF-1   Janssen et al., 2008
# 2    ADEL      Neuropeptide     PDF-1   Janssen et al., 2008
# 3    ADEL  Neurotransmitter  Dopamine  McDonald et al., 2007
# 4    ADEL  Neurotransmitter  Dopamine       Suo et al., 2003
#
#                                         Evidence URL
# 0  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...
# 1  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...
# 2  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...
# 3       https://www.ncbi.nlm.nih.gov/pubmed/18094261
# 4       https://www.ncbi.nlm.nih.gov/pubmed/12887685
# 📄 Preview: c302/c302/data/NeuronConnectFormatted.xlsx
#   Neuron 1 Neuron 2 Type  Nbr
# 0     ADAL     ADAR   EJ    1
# 1     ADAL     ADEL   Rp    1
# 2     ADAL     ADFL   Rp    1
# 3     ADAL     ADFL   EJ    1
# 4     ADAL     AIAL   Rp    1
# 📄 Preview: c302/c302/data/SI 5 Connectome adjacency matrices.xlsx
#   Unnamed: 0  Unnamed: 1 Unnamed: 2 PHARYNX Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0        NaN         NaN        NaN     NaN        NaN        NaN        NaN
# 1        NaN         NaN        NaN     I1L        I1R        I2L        I2R
# 2    PHARYNX         NaN        I1L     NaN        NaN         10        NaN
# 3        NaN         NaN        I1R     NaN        NaN        NaN          6
# 4        NaN         NaN        I2L       2        NaN        NaN          3
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 447 Unnamed: 448  \
# 0        NaN        NaN        NaN  ...          NaN          NaN
# 1         I3         I4         I5  ...         VC06        vm2AL
# 2          3        NaN          2  ...          NaN          NaN
# 3          1        NaN          2  ...          NaN          NaN
# 4        NaN         13          2  ...          NaN          NaN
#
#   Unnamed: 449 Unnamed: 450 Unnamed: 451 Unnamed: 452 Unnamed: 453  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1        vm2AR        vm1AL        vm1AR        vm1PL        vm1PR
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#   Unnamed: 454 Unnamed: 455 Unnamed: 456
# 0          NaN          NaN          NaN
# 1        vm2PL        vm2PR          NaN
# 2          NaN          NaN          I1L
# 3          NaN          NaN          I1R
# 4          NaN          NaN          I2L
#
# [5 rows x 457 columns]
# 📄 Preview: c302/c302/data/aconnectome_white_1986_A.csv
#       pre post type synapses
# 0  ADAL\tADFL\telectrical\t1
# 1    ADAL\tAIBL\tchemical\t1
# 2    ADAL\tAIBR\tchemical\t2
# 3  ADAL\tASHL\telectrical\t1
# 4    ADAL\tAVAR\tchemical\t2
# 📄 Preview: c302/c302/data/aconnectome_white_1986_L4.csv
#    pre\tpost\ttype\tsynapses
# 0  ADAL\tADFL\telectrical\t2
# 1    ADAL\tAIBR\tchemical\t1
# 2  ADAL\tASHL\telectrical\t6
# 3    ADAL\tAVAL\tchemical\t2
# 4    ADAL\tAVAR\tchemical\t1
# 📄 Preview: c302/c302/data/aconnectome_white_1986_whole.csv
#    pre\tpost\ttype\tsynapses
# 0  ADAL\tADFL\telectrical\t1
# 1    ADAL\tAIBL\tchemical\t1
# 2    ADAL\tAIBR\tchemical\t2
# 3  ADAL\tASHL\telectrical\t1
# 4    ADAL\tAVAR\tchemical\t2
# 📄 Preview: c302/c302/data/herm_full_edgelist.csv
#   Source           Target  Weight      Type
# 0   I1L    I2L                 10  chemical
# 1   I1L    I3                   3  chemical
# 2   I1L    I5                   2  chemical
# 3   I1L    I6                   1  chemical
# 4   I1L    M2L                  3  chemical
# 📄 Preview: c302/c302/data/herm_full_edgelist_MODIFIED.csv
#   Source           Target  Weight      Type
# 0   I1L    I2L                 10  chemical
# 1   I1L    I3                   3  chemical
# 2   I1L    I5                   2  chemical
# 3   I1L    I6                   1  chemical
# 4   I1L    M2L                  3  chemical
# 📄 Preview: c302/c302/data/synapse_count_matrices.xlsx
#   Unnamed: 0 Unnamed: 1 Unnamed: 2      Pre Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0        NaN        NaN        NaN  Sensory        NaN        NaN        NaN
# 1        NaN        NaN        NaN     ADFL       ADFR       ADLL       ADLR
# 2        NaN        NaN        NaN      NaN        NaN        NaN        NaN
# 3       Post    Sensory       ADFL        0          0          0          0
# 4        NaN        NaN       ADFR        0          0          0          0
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 173 Unnamed: 174  \
# 0        NaN        NaN        NaN  ...          NaN          NaN
# 1       AFDL       AFDR       ALML  ...         PVNL         PVNR
# 2        NaN        NaN        NaN  ...          NaN          NaN
# 3          1          0          0  ...            0            0
# 4          0          0          0  ...            0            0
#
#   Unnamed: 175 Unnamed: 176 Unnamed: 177 Unnamed: 178 Unnamed: 179  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1         PVQL         PVQR         RICL         RICR          RID
# 2          NaN          NaN          NaN          NaN          NaN
# 3            0            0            0            0            0
# 4            0            0            0            0            0
#
#   Unnamed: 180 Unnamed: 181 Unnamed: 182
# 0          NaN          NaN          NaN
# 1          RIS         RMGL         RMGR
# 2          NaN          NaN          NaN
# 3            0            0            0
# 4            0            0            0
#
# [5 rows x 183 columns]
# 📄 Preview: c302/c302/data/witvliet_2020_1.xlsx
#     pre  post        type  synapses
# 0  ADAL  ADAR  electrical         1
# 1  ADAL  AIBR    chemical         1
# 2  ADAL  ASHL  electrical         9
# 3  ADAL  ASKL  electrical         1
# 4  ADAL  AVAL    chemical         1
# 📄 Preview: c302/c302/data/witvliet_2020_2.xlsx
#     pre  post        type  synapses
# 0  ADAL  ADAR  electrical         1
# 1  ADAL  AIBR    chemical         1
# 2  ADAL  ASHL  electrical         2
# 3  ADAL  AVAR    chemical         2
# 4  ADAL  AVBL    chemical         1
# 📄 Preview: c302/c302/data/witvliet_2020_3.xlsx
#     pre  post        type  synapses
# 0  ADAL  ADAR  electrical         1
# 1  ADAL  ADFL  electrical         1
# 2  ADAL  ASHL  electrical         1
# 3  ADAL  ASKL  electrical         1
# 4  ADAL  AVAL    chemical         1
# 📄 Preview: c302/c302/data/witvliet_2020_4.xlsx
#     pre  post        type  synapses
# 0  ADAL  ADAR  electrical         1
# 1  ADAL  AIBR    chemical         1
# 2  ADAL  AIZL    chemical         1
# 3  ADAL  ASHL  electrical         1
# 4  ADAL  ASKL  electrical         1
# 📄 Preview: c302/c302/data/witvliet_2020_5.xlsx
#     pre  post        type  synapses
# 0  ADAL  ADFL  electrical         1
# 1  ADAL  ASHL    chemical         1
# 2  ADAL  ASHL  electrical         3
# 3  ADAL  ASKL  electrical         1
# 4  ADAL  AVAL    chemical         1
# 📄 Preview: c302/c302/data/witvliet_2020_6.xlsx
#     pre  post        type  synapses
# 0  ADAL  AIAL    chemical         1
# 1  ADAL  AIBL    chemical         1
# 2  ADAL  ASHL  electrical         2
# 3  ADAL  AVAL    chemical         3
# 4  ADAL  AVAR    chemical         1
# 📄 Preview: c302/c302/data/witvliet_2020_7.xlsx
#     pre  post      type  synapses
# 0  ADAL  AIAL  chemical         2
# 1  ADAL  AIBL  chemical         2
# 2  ADAL  AIBR  chemical         1
# 3  ADAL  AVAL  chemical         1
# 4  ADAL  AVBL  chemical         7
# 📄 Preview: c302/c302/data/witvliet_2020_8.xlsx
#     pre  post        type  synapses
# 0  ADAL  ADAR  electrical         1
# 1  ADAL  ASHL  electrical         1
# 2  ADAL  AVAL    chemical         2
# 3  ADAL  AVAR    chemical         1
# 4  ADAL  AVBL    chemical        16
# 📄 Preview: celegans_connectome_data/consensus_connectome_full_nofunc.csv
#   from_neuron to_neuron              from_pos                  to_pos  \
# 0        ADAL      ADAL  (0.03, 94.34, 10.31)    (0.03, 94.34, 10.31)
# 1        ADAL      ADAR  (0.03, 94.34, 10.31)  (-1.43, 91.22, -11.64)
# 2        ADAL      ADEL  (0.03, 94.34, 10.31)    (-0.12, 87.97, 10.5)
# 3        ADAL      ADER  (0.03, 94.34, 10.31)  (-0.58, 83.23, -11.47)
# 4        ADAL      ADFL  (0.03, 94.34, 10.31)      (8.48, 54.18, 7.0)
#
#   from_type  to_type  mean_gap_weight  mean_chem_weight  uncertainty  \
# 0     inter    inter              NaN               6.0          NaN
# 1     inter    inter         2.000000               NaN          NaN
# 2     inter  sensory              NaN               NaN          NaN
# 3     inter  sensory              NaN               NaN          NaN
# 4     inter  sensory         2.666667               NaN          NaN
#
#                                         data_sources
# 0                                       ['cook2019']
# 1  ['chklovskii', 'cook2019', 'funconn', 'openwor...
# 2                                                 []
# 3                                        ['funconn']
# 4  ['chklovskii', 'cook2019', 'openworm', 'white1...
# 📄 Preview: celegans_connectome_data/consensus_connectome_full_withfunc.csv
#   from_neuron to_neuron              from_pos                  to_pos  \
# 0        ADAL      ADAL  (0.03, 94.34, 10.31)    (0.03, 94.34, 10.31)
# 1        ADAL      ADAR  (0.03, 94.34, 10.31)  (-1.43, 91.22, -11.64)
# 2        ADAL      ADEL  (0.03, 94.34, 10.31)    (-0.12, 87.97, 10.5)
# 3        ADAL      ADER  (0.03, 94.34, 10.31)  (-0.58, 83.23, -11.47)
# 4        ADAL      ADFL  (0.03, 94.34, 10.31)      (8.48, 54.18, 7.0)
#
#   from_type  to_type  mean_gap_weight  mean_chem_weight  uncertainty  \
# 0     inter    inter              NaN               6.0          NaN
# 1     inter    inter         2.000000               NaN          NaN
# 2     inter  sensory              NaN               NaN          NaN
# 3     inter  sensory              NaN               NaN          NaN
# 4     inter  sensory         2.666667               NaN          NaN
#
#    functional_weight                                       data_sources
# 0                NaN                                       ['cook2019']
# 1           0.091616  ['chklovskii', 'cook2019', 'funconn', 'openwor...
# 2                NaN                                                 []
# 3           0.014166                                        ['funconn']
# 4                NaN  ['chklovskii', 'cook2019', 'openworm', 'white1...
# 📄 Preview: celegans_connectome_data/consensus_connectome_trimmed_nofunc.csv
#   from_neuron to_neuron              from_pos                  to_pos  \
# 0        ADAL      ADAL  (0.03, 94.34, 10.31)    (0.03, 94.34, 10.31)
# 1        ADAL      ADAR  (0.03, 94.34, 10.31)  (-1.43, 91.22, -11.64)
# 2        ADAL      ADFL  (0.03, 94.34, 10.31)      (8.48, 54.18, 7.0)
# 3        ADAL      ADLL  (0.03, 94.34, 10.31)    (12.05, 59.13, 3.86)
# 4        ADAL      AIAL  (0.03, 94.34, 10.31)    (-4.67, 66.74, 0.66)
#
#   from_type  to_type  mean_gap_weight  mean_chem_weight  uncertainty  \
# 0     inter    inter              NaN               6.0          NaN
# 1     inter    inter         2.000000               NaN          NaN
# 2     inter  sensory         2.666667               NaN          NaN
# 3     inter  sensory              NaN               2.0          NaN
# 4     inter    inter              NaN               2.0          NaN
#
#                                         data_sources
# 0                                       ['cook2019']
# 1  ['chklovskii', 'cook2019', 'funconn', 'openwor...
# 2  ['chklovskii', 'cook2019', 'openworm', 'white1...
# 3                                       ['cook2019']
# 4                     ['cook2019', 'witvliet2020_7']
# 📄 Preview: celegans_connectome_data/consensus_connectome_trimmed_withfunc.csv
#   from_neuron to_neuron              from_pos                  to_pos  \
# 0        ADAL      ADAL  (0.03, 94.34, 10.31)    (0.03, 94.34, 10.31)
# 1        ADAL      ADAR  (0.03, 94.34, 10.31)  (-1.43, 91.22, -11.64)
# 2        ADAL      ADER  (0.03, 94.34, 10.31)  (-0.58, 83.23, -11.47)
# 3        ADAL      ADFL  (0.03, 94.34, 10.31)      (8.48, 54.18, 7.0)
# 4        ADAL      ADLL  (0.03, 94.34, 10.31)    (12.05, 59.13, 3.86)
#
#   from_type  to_type  mean_gap_weight  mean_chem_weight  uncertainty  \
# 0     inter    inter              NaN               6.0          NaN
# 1     inter    inter         2.000000               NaN          NaN
# 2     inter  sensory              NaN               NaN          NaN
# 3     inter  sensory         2.666667               NaN          NaN
# 4     inter  sensory              NaN               2.0          NaN
#
#    functional_weight                                       data_sources
# 0                NaN                                       ['cook2019']
# 1           0.091616  ['chklovskii', 'cook2019', 'funconn', 'openwor...
# 2           0.014166                                        ['funconn']
# 3                NaN  ['chklovskii', 'cook2019', 'openworm', 'white1...
# 4                NaN                                       ['cook2019']
# 📄 Preview: file_index_master.csv
#     neuron                                 filename  \
# 0  unknown  c_elegans_connectome_simplified.graphml
# 1  unknown                           connectome.pdf
# 2  unknown                           celegans.ipynb
# 3  unknown                  NeuronLineage_Part2.xls
# 4  unknown             c_elegans_connectome.graphml
#
#                                            full_path extension modality  \
# 0  /home/rohit/Desktop/Projects/C-Elegans/c_elega...  .graphml    other
# 1  /home/rohit/Desktop/Projects/C-Elegans/connect...      .pdf    other
# 2  /home/rohit/Desktop/Projects/C-Elegans/celegan...    .ipynb    other
# 3  /home/rohit/Desktop/Projects/C-Elegans/NeuronL...      .xls    other
# 4  /home/rohit/Desktop/Projects/C-Elegans/c_elega...  .graphml    other
#
#                                 directory
# 0  /home/rohit/Desktop/Projects/C-Elegans
# 1  /home/rohit/Desktop/Projects/C-Elegans
# 2  /home/rohit/Desktop/Projects/C-Elegans
# 3  /home/rohit/Desktop/Projects/C-Elegans
# 4  /home/rohit/Desktop/Projects/C-Elegans
# 📄 Preview: merged_edges.csv
#   Source Target        Type  SynapseCount            SourceFile
# 0   ADAL   ADAR  electrical             1  witvliet_2020_2.xlsx
# 1   ADAL   AIBR    chemical             1  witvliet_2020_2.xlsx
# 2   ADAL   ASHL  electrical             2  witvliet_2020_2.xlsx
# 3   ADAL   AVAR    chemical             2  witvliet_2020_2.xlsx
# 4   ADAL   AVBL    chemical             1  witvliet_2020_2.xlsx
# 📄 Preview: merged_edges_with_relatedness.csv
#   Source   Target      Type  SynapseCount            SourceFile  Relatedness
# 0   AINL  CEPshVR  chemical             1  witvliet_2020_2.xlsx         17.0
# 1   AINR  CEPshDL  chemical             1  witvliet_2020_2.xlsx         16.0
# 2    ALA  CEPshVL  chemical             1  witvliet_2020_2.xlsx         14.0
# 3    ALA  CEPshVR  chemical             3  witvliet_2020_2.xlsx         18.0
# 4   ASIR  CEPshDR  chemical             1  witvliet_2020_2.xlsx         14.0
# 📄 Preview: merged_lineage_table.csv
#   NeuronA NeuronB  Relatedness
# 0    ADAL    ADAR         17.0
# 1    ADAL    ADEL          1.0
# 2    ADAL    ADER         17.0
# 3    ADAL    ADFL         18.0
# 4    ADAL    ADFR         16.0

# %%
# 📍 Key merged datasets
MERGED_EDGES_PATH = BASE_DIR / "merged_edges.csv"
MERGED_EDGES_WITH_REL_PATH = BASE_DIR / "merged_edges_with_relatedness.csv"
LINEAGE_PATH = BASE_DIR / "merged_lineage_table.csv"

# 📍 Alternative raw sources (for future validation)
CELEGANS_RAW_FOLDER = BASE_DIR / "c302/c302/data/"

# %%
# Load main files
edges_df = pd.read_csv(MERGED_EDGES_PATH)
edges_rel_df = pd.read_csv(MERGED_EDGES_WITH_REL_PATH)
lineage_df = pd.read_csv(LINEAGE_PATH)

# Quick inspections
display(edges_df.head())
display(edges_rel_df.head())
display(lineage_df.head())

print(f"🧠 Unique neurons in edges: {len(set(edges_df['Source']) | set(edges_df['Target']))}")
print(f"🧬 Lineage pairs: {len(lineage_df)}")
# Out:
#   Source Target        Type  SynapseCount            SourceFile
# 0   ADAL   ADAR  electrical             1  witvliet_2020_2.xlsx
# 1   ADAL   AIBR    chemical             1  witvliet_2020_2.xlsx
# 2   ADAL   ASHL  electrical             2  witvliet_2020_2.xlsx
# 3   ADAL   AVAR    chemical             2  witvliet_2020_2.xlsx
# 4   ADAL   AVBL    chemical             1  witvliet_2020_2.xlsx
#   Source   Target      Type  SynapseCount            SourceFile  Relatedness
# 0   AINL  CEPshVR  chemical             1  witvliet_2020_2.xlsx         17.0
# 1   AINR  CEPshDL  chemical             1  witvliet_2020_2.xlsx         16.0
# 2    ALA  CEPshVL  chemical             1  witvliet_2020_2.xlsx         14.0
# 3    ALA  CEPshVR  chemical             3  witvliet_2020_2.xlsx         18.0
# 4   ASIR  CEPshDR  chemical             1  witvliet_2020_2.xlsx         14.0
#   NeuronA NeuronB  Relatedness
# 0    ADAL    ADAR         17.0
# 1    ADAL    ADEL          1.0
# 2    ADAL    ADER         17.0
# 3    ADAL    ADFL         18.0
# 4    ADAL    ADFR         16.0
# 🧠 Unique neurons in edges: 1533
# 🧬 Lineage pairs: 38781

# %%
import yaml

catalog = {
    "merged_edges": {
        "path": str(MERGED_EDGES_PATH),
        "rows": len(edges_df),
        "columns": list(edges_df.columns),
        "description": "Merged chemical and electrical synapses across Witvliet datasets"
    },
    "merged_edges_with_relatedness": {
        "path": str(MERGED_EDGES_WITH_REL_PATH),
        "rows": len(edges_rel_df),
        "columns": list(edges_rel_df.columns),
        "description": "Edges merged with lineage-based relatedness scores"
    },
    "merged_lineage_table": {
        "path": str(LINEAGE_PATH),
        "rows": len(lineage_df),
        "columns": list(lineage_df.columns),
        "description": "Pairwise lineage distances from developmental tree"
    }
}

with open(BASE_DIR / "data_catalog.yml", "w") as f:
    yaml.dump(catalog, f, sort_keys=False)

print("✅ Data catalog created → data_catalog.yml")
# Out:
# ✅ Data catalog created → data_catalog.yml

# %%
# Union of all unique neurons across source/target and lineage
unique_neurons = set(edges_df['Source']) | set(edges_df['Target']) | set(lineage_df['NeuronA']) | set(lineage_df['NeuronB'])

with open(BASE_DIR / "unique_neuron_names.txt", "w") as f:
    for name in sorted(unique_neurons):
        f.write(name + "\n")

print(f"🧠 {len(unique_neurons)} unique neurons saved to unique_neuron_names.txt")
# Out:
# 🧠 1632 unique neurons saved to unique_neuron_names.txt

# %%
# 📦 Required imports
import os
import pandas as pd
import yaml
from pathlib import Path
from tqdm import tqdm

# 🧠 Heuristic classification based on file contents
def classify_data_type(columns, extension):
    colset = set([col.strip().lower() for col in columns])

    if 'source' in colset and 'target' in colset:
        return 'edges'
    if 'neurona' in colset and 'neuronb' in colset:
        return 'lineage'
    if 'from_neuron' in colset and 'to_neuron' in colset:
        return 'coordinates_edges'
    if 'neuron 1' in colset and 'neuron 2' in colset:
        return 'formatted_edges'
    if 'pre' in colset and 'post' in colset and 'type' in colset:
        return 'legacy_edges'
    if 'entity1' in colset and 'relationship' in colset:
        return 'expression_data'
    if extension in ['.nml', '.neuroml']:
        return 'neuroml'
    if extension == '.graphml':
        return 'graphml'
    return 'unknown'

# 📂 Define the base directory to scan
BASE_DIR = Path('/home/rohit/Desktop/Projects/C-Elegans')

# 📋 Data collection
file_records = []

for root, dirs, files in os.walk(BASE_DIR):
    for file in files:
        path = Path(root) / file
        size_kb = path.stat().st_size / 1024
        ext = path.suffix.lower()

        record = {
            'filename': file,
            'full_path': str(path),
            'size_kb': round(size_kb, 2),
            'extension': ext,
            'data_type': None,
            'num_rows': None,
            'num_columns': None,
            'column_names': None,
        }

        # Try to parse with pandas to extract structure
        if ext in ['.csv', '.tsv', '.xls', '.xlsx']:
            try:
                if ext == '.csv':
                    df = pd.read_csv(path, nrows=5)
                elif ext == '.tsv':
                    df = pd.read_csv(path, sep='\t', nrows=5)
                else:
                    df = pd.read_excel(path, nrows=5)

                record['num_rows'], record['num_columns'] = df.shape
                record['column_names'] = df.columns.tolist()
                record['data_type'] = classify_data_type(df.columns, ext)
            except Exception as e:
                record['data_type'] = 'unreadable'
        elif ext in ['.nml', '.neuroml', '.graphml']:
            record['data_type'] = classify_data_type([], ext)

        file_records.append(record)

# 📄 Save to CSV
inventory_df = pd.DataFrame(file_records)
inventory_df.to_csv("structured_data_inventory.csv", index=False)

# 📝 Save to YAML (for indexing)
yaml_catalog = {
    'files': [
        {
            'path': rec['full_path'],
            'extension': rec['extension'],
            'size_kb': rec['size_kb'],
            'data_type': rec['data_type'],
            'num_rows': rec['num_rows'],
            'num_columns': rec['num_columns'],
        }
        for rec in file_records
    ]
}

with open("data_catalog.yml", "w") as f:
    yaml.dump(yaml_catalog, f)

print("✅ Scan complete.")
print(f"🗃️  Total files scanned: {len(file_records)}")
print("📄 Output saved to: structured_data_inventory.csv and data_catalog.yml")
# Out:
# ✅ Scan complete.
# 🗃️  Total files scanned: 3221
# 📄 Output saved to: structured_data_inventory.csv and data_catalog.yml

# %%
import os

base_dir = "/home/rohit/Desktop/Projects/C-Elegans/data"

subdirs = [
    "connectivity/raw", "connectivity/processed",
    "lineage/raw", "lineage/processed",
    "neuroml/cell_library", "neuroml/circuits",
    "metadata", "temp"
]

for sub in subdirs:
    os.makedirs(os.path.join(base_dir, sub), exist_ok=True)

print("✅ Directory structure created.")
# Out:
# ✅ Directory structure created.

# %%
import pandas as pd

inventory_path = "/home/rohit/Desktop/Projects/C-Elegans/structured_data_inventory.csv"
inventory = pd.read_csv(inventory_path)

print("📄 Columns in structured_data_inventory.csv:")
print(inventory.columns.tolist())
# Out:
# 📄 Columns in structured_data_inventory.csv:
# ['filename', 'full_path', 'size_kb', 'extension', 'data_type', 'num_rows', 'num_columns', 'column_names']

# %%
import pandas as pd
import os

# Load the inventory
inventory = pd.read_csv("/home/rohit/Desktop/Projects/C-Elegans/structured_data_inventory.csv")
base_data_dir = "/home/rohit/Desktop/Projects/C-Elegans/data"

# Heuristic category assignment
def classify_row(row):
    name = row['filename'].lower()
    path = row['full_path'].lower()

    if "witvliet" in name or "white" in name or "herm" in name or "adjacency" in name:
        return "connectivity/raw"
    elif "merged_edges" in name or "consensus_connectome" in name:
        return "connectivity/processed"
    elif "lineage" in name or "relatedness" in name:
        return "lineage/raw" if "merged" not in name else "lineage/processed"
    elif name.endswith(".nml") or "cell" in name or "neuron" in name:
        return "neuroml/cell_library"
    elif "circuit" in name or "network" in name:
        return "neuroml/circuits"
    elif "file_index" in name or "data_catalog" in name:
        return "metadata"
    else:
        return "temp"

# Construct the manifest
manifest = inventory.copy()
manifest['original_path'] = manifest['full_path']
manifest['category'] = manifest.apply(classify_row, axis=1)
manifest['canonical_path'] = manifest.apply(
    lambda row: os.path.join(base_data_dir, row['category'], row['filename']),
    axis=1
)
manifest['notes'] = manifest['extension'].apply(lambda ext: "🧪 CSV" if ext == '.csv' else "")

# Final columns
manifest = manifest[['original_path', 'filename', 'canonical_path', 'category', 'notes']]

# Save
os.makedirs("/home/rohit/Desktop/Projects/C-Elegans/utils", exist_ok=True)
manifest_path = "/home/rohit/Desktop/Projects/C-Elegans/utils/data_restructure_manifest.csv"
manifest.to_csv(manifest_path, index=False)

print(f"✅ Saved manifest → {manifest_path}")
# Out:
# ✅ Saved manifest → /home/rohit/Desktop/Projects/C-Elegans/utils/data_restructure_manifest.csv

# %%
import os
import shutil
import pandas as pd

# Load the manifest
manifest_path = "/home/rohit/Desktop/Projects/C-Elegans/utils/data_restructure_manifest.csv"
manifest = pd.read_csv(manifest_path)

# Move each file
for idx, row in manifest.iterrows():
    src = row['original_path']
    dst = row['canonical_path']
    dst_dir = os.path.dirname(dst)

    try:
        os.makedirs(dst_dir, exist_ok=True)
        if os.path.exists(src):
            shutil.move(src, dst)
            print(f"✅ Moved: {src} → {dst}")
        else:
            print(f"⚠️ Missing: {src}")
    except Exception as e:
        print(f"❌ Error moving {src} → {dst}: {e}")
# Out:
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/connectome.pdf → /home/rohit/Desktop/Projects/C-Elegans/data/temp/connectome.pdf
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/merged_edges_with_relatedness.csv → /home/rohit/Desktop/Projects/C-Elegans/data/connectivity/processed/merged_edges_with_relatedness.csv
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/celegans.ipynb → /home/rohit/Desktop/Projects/C-Elegans/data/temp/celegans.ipynb
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/NeuronLineage_Part2.xls → /home/rohit/Desktop/Projects/C-Elegans/data/lineage/raw/NeuronLineage_Part2.xls
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/merged_lineage_table.csv → /home/rohit/Desktop/Projects/C-Elegans/data/lineage/processed/merged_lineage_table.csv
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/merged_edges.csv → /home/rohit/Desktop/Projects/C-Elegans/data/connectivity/processed/merged_edges.csv
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/celegans.pdf → /home/rohit/Desktop/Projects/C-Elegans/data/temp/celegans.pdf
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/NeuronLineage_Part1.xls → /home/rohit/Desktop/Projects/C-Elegans/data/lineage/raw/NeuronLineage_Part1.xls
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/file_index_master.csv → /home/rohit/Desktop/Projects/C-Elegans/data/metadata/file_index_master.csv
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/phase0.ipynb → /home/rohit/Desktop/Projects/C-Elegans/data/temp/phase0.ipynb
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/connectome.ipynb → /home/rohit/Desktop/Projects/C-Elegans/data/temp/connectome.ipynb
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/unique_neuron_names.txt → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/unique_neuron_names.txt
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/data_catalog.yml → /home/rohit/Desktop/Projects/C-Elegans/data/metadata/data_catalog.yml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/_osb.yml → /home/rohit/Desktop/Projects/C-Elegans/data/temp/_osb.yml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/.openworm.yml → /home/rohit/Desktop/Projects/C-Elegans/data/temp/.openworm.yml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/cells.md → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/cells.md
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/.gitignore → /home/rohit/Desktop/Projects/C-Elegans/data/temp/.gitignore
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/OpenWormOverview.md → /home/rohit/Desktop/Projects/C-Elegans/data/temp/OpenWormOverview.md
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/README.md → /home/rohit/Desktop/Projects/C-Elegans/data/temp/README.md
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/.test.pharyngealC.mep → /home/rohit/Desktop/Projects/C-Elegans/data/temp/.test.pharyngealC.mep
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/LEMS_c302_A_Syns.xml → /home/rohit/Desktop/Projects/C-Elegans/data/temp/LEMS_c302_A_Syns.xml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/.test.pharC1.jnmlnrn.omt → /home/rohit/Desktop/Projects/C-Elegans/data/temp/.test.pharC1.jnmlnrn.omt
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/c302_C1_Full.net.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/c302_C1_Full.net.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/c302_B_Oscillator.net.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/c302_B_Oscillator.net.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/LEMS_c302_C_Oscillator.xml → /home/rohit/Desktop/Projects/C-Elegans/data/temp/LEMS_c302_C_Oscillator.xml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/c302_C2_IClamp.net.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/c302_C2_IClamp.net.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/c302_A_IClamp.net.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/c302_A_IClamp.net.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/LEMS_c302_A_Full.xml → /home/rohit/Desktop/Projects/C-Elegans/data/temp/LEMS_c302_A_Full.xml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/.test.pharA.jnmlnrn.omt → /home/rohit/Desktop/Projects/C-Elegans/data/temp/.test.pharA.jnmlnrn.omt
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/LEMS_c302_C1_Full.xml → /home/rohit/Desktop/Projects/C-Elegans/data/temp/LEMS_c302_C1_Full.xml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/c302_A_Full.net.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/c302_A_Full.net.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/custom_muscle_components.xml → /home/rohit/Desktop/Projects/C-Elegans/data/temp/custom_muscle_components.xml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/LEMS_c302_D_IClamp.xml → /home/rohit/Desktop/Projects/C-Elegans/data/temp/LEMS_c302_D_IClamp.xml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/c302_D_Social.net.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/c302_D_Social.net.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/.test.pharC0.jnmlnrn.omt → /home/rohit/Desktop/Projects/C-Elegans/data/temp/.test.pharC0.jnmlnrn.omt
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/LEMS_c302_C0_Oscillator.xml → /home/rohit/Desktop/Projects/C-Elegans/data/temp/LEMS_c302_C0_Oscillator.xml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/LEMS_c302_D1_IClamp.xml → /home/rohit/Desktop/Projects/C-Elegans/data/temp/LEMS_c302_D1_IClamp.xml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/c302_A_Muscles.net.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/c302_A_Muscles.net.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/c302_C0_Syns.net.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/c302_C0_Syns.net.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/LEMS_c302_C_IClamp.xml → /home/rohit/Desktop/Projects/C-Elegans/data/temp/LEMS_c302_C_IClamp.xml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/LEMS_c302_A_Social.xml → /home/rohit/Desktop/Projects/C-Elegans/data/temp/LEMS_c302_A_Social.xml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/.test.pharD.jnmlnrn.omt → /home/rohit/Desktop/Projects/C-Elegans/data/temp/.test.pharD.jnmlnrn.omt
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/c302_B_Social.net.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/c302_B_Social.net.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/LEMS_c302_W2D_Syns.xml → /home/rohit/Desktop/Projects/C-Elegans/data/temp/LEMS_c302_W2D_Syns.xml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/LEMS_c302_D1_Syns.xml → /home/rohit/Desktop/Projects/C-Elegans/data/temp/LEMS_c302_D1_Syns.xml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/LEMS_c302_C0_Full.xml → /home/rohit/Desktop/Projects/C-Elegans/data/temp/LEMS_c302_C0_Full.xml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/LEMS_c302_D1_Oscillator.xml → /home/rohit/Desktop/Projects/C-Elegans/data/temp/LEMS_c302_D1_Oscillator.xml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/LEMS_c302_D_Social.xml → /home/rohit/Desktop/Projects/C-Elegans/data/temp/LEMS_c302_D_Social.xml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/c302_D1_RIA.net.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/c302_D1_RIA.net.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/c302_W2D_Muscles.net.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/c302_W2D_Muscles.net.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/LEMS_c302_A_Oscillator.xml → /home/rohit/Desktop/Projects/C-Elegans/data/temp/LEMS_c302_A_Oscillator.xml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/LEMS_c302_W2D_Social.xml → /home/rohit/Desktop/Projects/C-Elegans/data/temp/LEMS_c302_W2D_Social.xml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/c302_C2_FW.net.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/c302_C2_FW.net.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/LEMS_c302_D_Oscillator.xml → /home/rohit/Desktop/Projects/C-Elegans/data/temp/LEMS_c302_D_Oscillator.xml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/LEMS_c302_C1_Pharyngeal.xml → /home/rohit/Desktop/Projects/C-Elegans/data/temp/LEMS_c302_C1_Pharyngeal.xml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/LEMS_c302_C0_IClamp.xml → /home/rohit/Desktop/Projects/C-Elegans/data/temp/LEMS_c302_C0_IClamp.xml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/c302_A_Oscillator.net.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/c302_A_Oscillator.net.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/LEMS_c302_D1_Muscles.xml → /home/rohit/Desktop/Projects/C-Elegans/data/temp/LEMS_c302_D1_Muscles.xml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/c302_C_IClamp.net.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/c302_C_IClamp.net.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/.test.pharyngealA.mep → /home/rohit/Desktop/Projects/C-Elegans/data/temp/.test.pharyngealA.mep
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/LEMS_c302_C0_Pharyngeal.xml → /home/rohit/Desktop/Projects/C-Elegans/data/temp/LEMS_c302_C0_Pharyngeal.xml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/LEMS_c302_W2D_Oscillator.xml → /home/rohit/Desktop/Projects/C-Elegans/data/temp/LEMS_c302_W2D_Oscillator.xml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/c302_C_Oscillator.net.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/c302_C_Oscillator.net.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/c302_C0_Oscillator.net.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/c302_C0_Oscillator.net.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/LEMS_c302_C_Muscles.xml → /home/rohit/Desktop/Projects/C-Elegans/data/temp/LEMS_c302_C_Muscles.xml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/c302_W2D_Full.net.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/c302_W2D_Full.net.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/c302_C1_Oscillator.net.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/c302_C1_Oscillator.net.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/LEMS_c302_C0_Social.xml → /home/rohit/Desktop/Projects/C-Elegans/data/temp/LEMS_c302_C0_Social.xml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/c302_C1_Social.net.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/c302_C1_Social.net.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/c302_D_Oscillator.net.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/c302_D_Oscillator.net.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/LEMS_c302_C0_Muscles.xml → /home/rohit/Desktop/Projects/C-Elegans/data/temp/LEMS_c302_C0_Muscles.xml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/LEMS_c302_C1_Syns.xml → /home/rohit/Desktop/Projects/C-Elegans/data/temp/LEMS_c302_C1_Syns.xml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/LEMS_c302_B_Syns.xml → /home/rohit/Desktop/Projects/C-Elegans/data/temp/LEMS_c302_B_Syns.xml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/c302_W2D_Social.net.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/c302_W2D_Social.net.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/.test.pharyngealB.mep → /home/rohit/Desktop/Projects/C-Elegans/data/temp/.test.pharyngealB.mep
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/c302_A_Syns.net.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/c302_A_Syns.net.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/c302_D_IClamp.net.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/c302_D_IClamp.net.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/c302_D1_Pharyngeal.net.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/c302_D1_Pharyngeal.net.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/LEMS_c302_W2D_IClamp.xml → /home/rohit/Desktop/Projects/C-Elegans/data/temp/LEMS_c302_W2D_IClamp.xml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/LEMS_c302_D_Muscles.xml → /home/rohit/Desktop/Projects/C-Elegans/data/temp/LEMS_c302_D_Muscles.xml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/c302_C_Syns.net.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/c302_C_Syns.net.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/LEMS_c302_A_IClamp.xml → /home/rohit/Desktop/Projects/C-Elegans/data/temp/LEMS_c302_A_IClamp.xml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/.test.pharB.jnmlnrn.omt → /home/rohit/Desktop/Projects/C-Elegans/data/temp/.test.pharB.jnmlnrn.omt
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/LEMS_c302_C_Full.xml → /home/rohit/Desktop/Projects/C-Elegans/data/temp/LEMS_c302_C_Full.xml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/LEMS_c302_D1_Pharyngeal.xml → /home/rohit/Desktop/Projects/C-Elegans/data/temp/LEMS_c302_D1_Pharyngeal.xml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/LEMS_c302_B_Pharyngeal.xml → /home/rohit/Desktop/Projects/C-Elegans/data/temp/LEMS_c302_B_Pharyngeal.xml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/c302_D1_Full.net.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/c302_D1_Full.net.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/LEMS_c302_D1_Social.xml → /home/rohit/Desktop/Projects/C-Elegans/data/temp/LEMS_c302_D1_Social.xml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/LEMS_c302_W2D_Full.xml → /home/rohit/Desktop/Projects/C-Elegans/data/temp/LEMS_c302_W2D_Full.xml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/c302_B_Full.net.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/c302_B_Full.net.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/.test.pharyngealC0.mep → /home/rohit/Desktop/Projects/C-Elegans/data/temp/.test.pharyngealC0.mep
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/c302_C0_Full.net.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/c302_C0_Full.net.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/c302_C2_Muscles.net.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/c302_C2_Muscles.net.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/c302_W2D_Oscillator.net.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/c302_W2D_Oscillator.net.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/c302_D_Pharyngeal.net.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/c302_D_Pharyngeal.net.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/c302_C_Muscles.net.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/c302_C_Muscles.net.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/c302_D1_IClamp.net.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/c302_D1_IClamp.net.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/c302_D_Full.net.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/c302_D_Full.net.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/c302_C0_Social.net.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/c302_C0_Social.net.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/c302_C0_Pharyngeal.net.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/c302_C0_Pharyngeal.net.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/LEMS_c302_C2_Social.xml → /home/rohit/Desktop/Projects/C-Elegans/data/temp/LEMS_c302_C2_Social.xml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/.test.pharC.jnml.omt → /home/rohit/Desktop/Projects/C-Elegans/data/temp/.test.pharC.jnml.omt
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/c302_C1_Syns.net.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/c302_C1_Syns.net.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/.test.pharC0.jnml.omt → /home/rohit/Desktop/Projects/C-Elegans/data/temp/.test.pharC0.jnml.omt
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/LEMS_c302_A_Pharyngeal.xml → /home/rohit/Desktop/Projects/C-Elegans/data/temp/LEMS_c302_A_Pharyngeal.xml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/c302_D1_Oscillator.net.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/c302_D1_Oscillator.net.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/LEMS_c302_C_Syns.xml → /home/rohit/Desktop/Projects/C-Elegans/data/temp/LEMS_c302_C_Syns.xml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/cell_X.xml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/cell_X.xml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/.test.pharB.jnml.omt → /home/rohit/Desktop/Projects/C-Elegans/data/temp/.test.pharB.jnml.omt
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/LEMS_c302_C1_Muscles.xml → /home/rohit/Desktop/Projects/C-Elegans/data/temp/LEMS_c302_C1_Muscles.xml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/c302_D_Muscles.net.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/c302_D_Muscles.net.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/c302_D1_Muscles.net.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/c302_D1_Muscles.net.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/c302_C2_Syns.net.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/c302_C2_Syns.net.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/.test.validate.omt → /home/rohit/Desktop/Projects/C-Elegans/data/temp/.test.validate.omt
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/LEMS_c302_D_Pharyngeal.xml → /home/rohit/Desktop/Projects/C-Elegans/data/temp/LEMS_c302_D_Pharyngeal.xml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/c302_B_Muscles.net.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/c302_B_Muscles.net.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/cell_W2D.xml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/cell_W2D.xml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/.test.pharC.jnmlnrn.omt → /home/rohit/Desktop/Projects/C-Elegans/data/temp/.test.pharC.jnmlnrn.omt
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/c302_C2_Full.net.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/c302_C2_Full.net.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/.test.pharyngealC1.mep → /home/rohit/Desktop/Projects/C-Elegans/data/temp/.test.pharyngealC1.mep
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/LEMS_c302_B_Muscles.xml → /home/rohit/Desktop/Projects/C-Elegans/data/temp/LEMS_c302_B_Muscles.xml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/c302_C_Social.net.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/c302_C_Social.net.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/cell_B.xml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/cell_B.xml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/c302_W2D_Pharyngeal.net.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/c302_W2D_Pharyngeal.net.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/LEMS_c302_D_Syns.xml → /home/rohit/Desktop/Projects/C-Elegans/data/temp/LEMS_c302_D_Syns.xml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/LEMS_c302_B_Full.xml → /home/rohit/Desktop/Projects/C-Elegans/data/temp/LEMS_c302_B_Full.xml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/LEMS_c302_B_Social.xml → /home/rohit/Desktop/Projects/C-Elegans/data/temp/LEMS_c302_B_Social.xml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/.test.pharD1.jnmlnrn.omt → /home/rohit/Desktop/Projects/C-Elegans/data/temp/.test.pharD1.jnmlnrn.omt
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/c302_C2_Oscillator.net.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/c302_C2_Oscillator.net.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/c302_C_Pharyngeal.net.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/c302_C_Pharyngeal.net.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/LEMS_c302_C2_Oscillator.xml → /home/rohit/Desktop/Projects/C-Elegans/data/temp/LEMS_c302_C2_Oscillator.xml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/LEMS_c302_B_IClamp.xml → /home/rohit/Desktop/Projects/C-Elegans/data/temp/LEMS_c302_B_IClamp.xml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/LEMS_c302_C1_IClamp.xml → /home/rohit/Desktop/Projects/C-Elegans/data/temp/LEMS_c302_C1_IClamp.xml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/LEMS_c302_C_Social.xml → /home/rohit/Desktop/Projects/C-Elegans/data/temp/LEMS_c302_C_Social.xml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/.test.pharC1.jnml.omt → /home/rohit/Desktop/Projects/C-Elegans/data/temp/.test.pharC1.jnml.omt
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/LEMS_c302_W2D_Pharyngeal.xml → /home/rohit/Desktop/Projects/C-Elegans/data/temp/LEMS_c302_W2D_Pharyngeal.xml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/LEMS_c302_W2D_Muscles.xml → /home/rohit/Desktop/Projects/C-Elegans/data/temp/LEMS_c302_W2D_Muscles.xml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/LEMS_c302_C_Pharyngeal.xml → /home/rohit/Desktop/Projects/C-Elegans/data/temp/LEMS_c302_C_Pharyngeal.xml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/c302_C1_IClamp.net.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/c302_C1_IClamp.net.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/c302_B_Pharyngeal.net.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/c302_B_Pharyngeal.net.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/custom_synapses.xml → /home/rohit/Desktop/Projects/C-Elegans/data/temp/custom_synapses.xml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/c302_A_Pharyngeal.net.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/c302_A_Pharyngeal.net.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/LEMS_c302_B_Oscillator.xml → /home/rohit/Desktop/Projects/C-Elegans/data/temp/LEMS_c302_B_Oscillator.xml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/c302_B_IClamp.net.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/c302_B_IClamp.net.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/.test.pharA.jnml.omt → /home/rohit/Desktop/Projects/C-Elegans/data/temp/.test.pharA.jnml.omt
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/c302_A_Social.net.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/c302_A_Social.net.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/LEMS_c302_C1_Social.xml → /home/rohit/Desktop/Projects/C-Elegans/data/temp/LEMS_c302_C1_Social.xml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/LEMS_c302_C2_IClamp.xml → /home/rohit/Desktop/Projects/C-Elegans/data/temp/LEMS_c302_C2_IClamp.xml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/LEMS_c302_C2_Pharyngeal.xml → /home/rohit/Desktop/Projects/C-Elegans/data/temp/LEMS_c302_C2_Pharyngeal.xml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/c302_C0_IClamp.net.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/c302_C0_IClamp.net.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/c302_D_Syns.net.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/c302_D_Syns.net.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/c302_C2_Social.net.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/c302_C2_Social.net.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/c302_B_Syns.net.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/c302_B_Syns.net.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/LEMS_c302_C2_Muscles.xml → /home/rohit/Desktop/Projects/C-Elegans/data/temp/LEMS_c302_C2_Muscles.xml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/cell_C.xml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/cell_C.xml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/c302_C2_Pharyngeal.net.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/c302_C2_Pharyngeal.net.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/LEMS_c302_C2_Syns.xml → /home/rohit/Desktop/Projects/C-Elegans/data/temp/LEMS_c302_C2_Syns.xml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/LEMS_c302_A_Muscles.xml → /home/rohit/Desktop/Projects/C-Elegans/data/temp/LEMS_c302_A_Muscles.xml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/LEMS_c302_D1_Full.xml → /home/rohit/Desktop/Projects/C-Elegans/data/temp/LEMS_c302_D1_Full.xml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/c302_W2D_IClamp.net.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/c302_W2D_IClamp.net.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/c302_C1_Pharyngeal.net.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/c302_C1_Pharyngeal.net.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/c302_C0_Muscles.net.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/c302_C0_Muscles.net.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/c302_D1_Syns.net.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/c302_D1_Syns.net.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/LEMS_c302_C2_Full.xml → /home/rohit/Desktop/Projects/C-Elegans/data/temp/LEMS_c302_C2_Full.xml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/LEMS_c302_C1_Oscillator.xml → /home/rohit/Desktop/Projects/C-Elegans/data/temp/LEMS_c302_C1_Oscillator.xml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/c302_C_Full.net.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/c302_C_Full.net.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/LEMS_c302_D_Full.xml → /home/rohit/Desktop/Projects/C-Elegans/data/temp/LEMS_c302_D_Full.xml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/c302_C1_Muscles.net.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/c302_C1_Muscles.net.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/c302_W2D_Syns.net.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/c302_W2D_Syns.net.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/LEMS_c302_C0_Syns.xml → /home/rohit/Desktop/Projects/C-Elegans/data/temp/LEMS_c302_C0_Syns.xml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/c302_D1_Social.net.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/c302_D1_Social.net.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/LEMS_c302_C2_FW.xml → /home/rohit/Desktop/Projects/C-Elegans/data/temp/LEMS_c302_C2_FW.xml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/parametersweep/.test.canonical.mep → /home/rohit/Desktop/Projects/C-Elegans/data/temp/.test.canonical.mep
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/parametersweep/info.html → /home/rohit/Desktop/Projects/C-Elegans/data/temp/info.html
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/parametersweep/IClamp_GenericMuscleCell.net.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/IClamp_GenericMuscleCell.net.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/parametersweep/Sweep.py → /home/rohit/Desktop/Projects/C-Elegans/data/temp/Sweep.py
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/parametersweep/.test.ex.jnmlnrn.omt → /home/rohit/Desktop/Projects/C-Elegans/data/temp/.test.ex.jnmlnrn.omt
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/parametersweep/firing_rates_GenericMuscleCell.png → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/firing_rates_GenericMuscleCell.png
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/parametersweep/test_ex0_jnml.py → /home/rohit/Desktop/Projects/C-Elegans/data/temp/test_ex0_jnml.py
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/parametersweep/heatmap_GenericMuscleCell.png → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/heatmap_GenericMuscleCell.png
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/parametersweep/GenericNeuronCell.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/GenericNeuronCell.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/parametersweep/Canonical_W2D.net.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/Canonical_W2D.net.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/parametersweep/SimCanonical_W2D.json → /home/rohit/Desktop/Projects/C-Elegans/data/temp/SimCanonical_W2D.json
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/parametersweep/test_syns.xml → /home/rohit/Desktop/Projects/C-Elegans/data/temp/test_syns.xml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/parametersweep/heatmap_GenericNeuronCell.png → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/heatmap_GenericNeuronCell.png
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/parametersweep/SimCanonical_C.json → /home/rohit/Desktop/Projects/C-Elegans/data/temp/SimCanonical_C.json
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/parametersweep/GenerateExamples.py → /home/rohit/Desktop/Projects/C-Elegans/data/temp/GenerateExamples.py
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/parametersweep/IClamp_GenericNeuronCell.json → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/IClamp_GenericNeuronCell.json
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/parametersweep/test_syns2.xml → /home/rohit/Desktop/Projects/C-Elegans/data/temp/test_syns2.xml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/parametersweep/.test.ex.mep → /home/rohit/Desktop/Projects/C-Elegans/data/temp/.test.ex.mep
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/parametersweep/Canonical_C.net.png → /home/rohit/Desktop/Projects/C-Elegans/data/temp/Canonical_C.net.png
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/parametersweep/Canonical_W2D.json → /home/rohit/Desktop/Projects/C-Elegans/data/temp/Canonical_W2D.json
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/parametersweep/Sim_IClamp_GenericMuscleCell.json → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/Sim_IClamp_GenericMuscleCell.json
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/parametersweep/regenerateAndTest.sh → /home/rohit/Desktop/Projects/C-Elegans/data/temp/regenerateAndTest.sh
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/parametersweep/test_ex_jnmlnrn.py → /home/rohit/Desktop/Projects/C-Elegans/data/temp/test_ex_jnmlnrn.py
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/parametersweep/Sim_IClamp_GenericNeuronCell.json → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/Sim_IClamp_GenericNeuronCell.json
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/parametersweep/firing_rates_GenericNeuronCellW2D.png → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/firing_rates_GenericNeuronCellW2D.png
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/parametersweep/.test.ex.omt → /home/rohit/Desktop/Projects/C-Elegans/data/temp/.test.ex.omt
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/parametersweep/Canonical_C.net.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/Canonical_C.net.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/parametersweep/mean_spike_frequency_GenericNeuronCell.png → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/mean_spike_frequency_GenericNeuronCell.png
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/parametersweep/.test.canonical.jnmlnrn.omt → /home/rohit/Desktop/Projects/C-Elegans/data/temp/.test.canonical.jnmlnrn.omt
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/parametersweep/firing_rates_GenericNeuronCell.png → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/firing_rates_GenericNeuronCell.png
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/parametersweep/IClamp_GenericNeuronCell.net.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/IClamp_GenericNeuronCell.net.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/parametersweep/Canonical_C.json → /home/rohit/Desktop/Projects/C-Elegans/data/temp/Canonical_C.json
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/parametersweep/test_ex0_jnmlnrn.py → /home/rohit/Desktop/Projects/C-Elegans/data/temp/test_ex0_jnmlnrn.py
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/parametersweep/Generate.py → /home/rohit/Desktop/Projects/C-Elegans/data/temp/Generate.py
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/parametersweep/IClamp_GenericMuscleCell.json → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/IClamp_GenericMuscleCell.json
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/parametersweep/test_ex_jnml.py → /home/rohit/Desktop/Projects/C-Elegans/data/temp/test_ex_jnml.py
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/parametersweep/.test.canonical.omt → /home/rohit/Desktop/Projects/C-Elegans/data/temp/.test.canonical.omt
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/parametersweep/README.md → /home/rohit/Desktop/Projects/C-Elegans/data/temp/README.md
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/parametersweep/mean_spike_frequency_GenericMuscleCell.png → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/mean_spike_frequency_GenericMuscleCell.png
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/parametersweep/cell_C.xml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/cell_C.xml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/parametersweep/clean.sh → /home/rohit/Desktop/Projects/C-Elegans/data/temp/clean.sh
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/parametersweep/CanonicalCircuit.py → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/circuits/CanonicalCircuit.py
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/parametersweep/GenericMuscleCell.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/GenericMuscleCell.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/summary/README.md → /home/rohit/Desktop/Projects/C-Elegans/data/temp/README.md
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/summary/images/.gitattributes → /home/rohit/Desktop/Projects/C-Elegans/data/temp/.gitattributes
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/cells/SMDVR.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/SMDVR.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/cells/URAVL.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/URAVL.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/cells/DB4_D.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/DB4_D.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/cells/DB6.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/DB6.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/cells/VD9.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/VD9.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/cells/ALMR_D.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/ALMR_D.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/cells/AVER_D.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/AVER_D.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/cells/VC1.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/VC1.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/cells/DA1.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/DA1.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/cells/IL1VL.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/IL1VL.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/cells/FLPR_D.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/FLPR_D.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/cells/AINR_D.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/AINR_D.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/cells/PVT_D.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/PVT_D.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/cells/AIZR_D.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/AIZR_D.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/cells/DD5.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/DD5.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/cells/DB3.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/DB3.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/cells/ASGR.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/ASGR.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/cells/URYDL.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/URYDL.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/cells/ALMR.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/ALMR.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/cells/PVQR_D.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/PVQR_D.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/cells/RIFL.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/RIFL.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/cells/PDA_D.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/PDA_D.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/cells/OLLR.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/OLLR.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/cells/SDQR_D.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/SDQR_D.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/cells/AWBL.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/AWBL.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/cells/VB10_D.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/VB10_D.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/cells/VC5.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/VC5.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/cells/IL1VL_D.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/IL1VL_D.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/cells/RMEV_D.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/RMEV_D.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/cells/IL2VL_D.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/IL2VL_D.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/cells/PVT.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/PVT.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/cells/DB7_D.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/DB7_D.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/cells/RIPL.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/RIPL.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/cells/I1L.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/I1L.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/cells/ALML_D.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/ALML_D.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/cells/MCL_D.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/MCL_D.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/cells/VA6.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/VA6.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/cells/SAADR.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/SAADR.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/cells/CEPVL.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/CEPVL.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/cells/SMBVR.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/SMBVR.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/cells/SAAVR.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/SAAVR.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/cells/VD2_D.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/VD2_D.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/cells/SMDDL.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/SMDDL.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/cells/URYDR_D.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/URYDR_D.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/cells/RIBL_D.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/RIBL_D.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/cells/PDA.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/PDA.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/cells/BAGL_D.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/BAGL_D.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/cells/PLNL_D.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/PLNL_D.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/cells/PVQR.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/PVQR.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/cells/PVM.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/PVM.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/cells/AVKL_D.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/AVKL_D.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/cells/AS1.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/AS1.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/cells/SIBDL.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/SIBDL.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/cells/DD1_D.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/DD1_D.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/cells/AVKL.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/AVKL.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/cells/VD11.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/VD11.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/cells/OLQDL.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/OLQDL.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/cells/VA7_D.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/VA7_D.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/cells/VA5.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/VA5.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/cells/ALNR_D.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/ALNR_D.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/cells/AINR.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/AINR.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/cells/ADAR.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/ADAR.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/cells/RMGR_D.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/RMGR_D.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/cells/AIMR.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/AIMR.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/cells/VB8.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/VB8.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/cells/ASGL.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/ASGL.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/cells/AIBL_D.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/AIBL_D.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/cells/LUAL.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/LUAL.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/cells/AWBL_D.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/AWBL_D.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/cells/IL1DR_D.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/IL1DR_D.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/c302/examples/cells/OLQVR_D.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/OLQVR_D.cell.nml
# ...
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/CElegansNeuroML/CElegans/generatedNeuroML2/AIZR.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/AIZR.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/CElegansNeuroML/CElegans/generatedNeuroML2/RMDVR.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/RMDVR.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/CElegansNeuroML/CElegans/generatedNeuroML2/Serotonin.synapse.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/Serotonin.synapse.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/CElegansNeuroML/CElegans/generatedNeuroML2/SIAVL.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/SIAVL.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/CElegansNeuroML/CElegans/generatedNeuroML2/VD7.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/VD7.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/CElegansNeuroML/CElegans/generatedNeuroML2/PVDL.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/PVDL.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/CElegansNeuroML/CElegans/generatedNeuroML2/AS10.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/AS10.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/CElegansNeuroML/CElegans/generatedNeuroML2/PLNR.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/PLNR.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/CElegansNeuroML/CElegans/generatedNeuroML2/VA3.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/VA3.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/CElegansNeuroML/CElegans/generatedNeuroML2/I2L.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/I2L.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/CElegansNeuroML/CElegans/generatedNeuroML2/CEPDL.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/CEPDL.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/CElegansNeuroML/CElegans/generatedNeuroML2/RIS.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/RIS.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/CElegansNeuroML/CElegans/generatedNeuroML2/PHBL.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/PHBL.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/CElegansNeuroML/CElegans/generatedNeuroML2/PVR.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/PVR.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/CElegansNeuroML/CElegans/generatedNeuroML2/AQR.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/AQR.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/CElegansNeuroML/CElegans/generatedNeuroML2/ADER.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/ADER.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/CElegansNeuroML/CElegans/generatedNeuroML2/ASKR.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/ASKR.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/CElegansNeuroML/CElegans/generatedNeuroML2/RMGR.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/RMGR.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/CElegansNeuroML/CElegans/generatedNeuroML2/VB7.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/VB7.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/CElegansNeuroML/CElegans/generatedNeuroML2/AINL.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/AINL.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/CElegansNeuroML/CElegans/generatedNeuroML2/AS5.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/AS5.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/CElegansNeuroML/CElegans/generatedNeuroML2/AVFR.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/AVFR.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/CElegansNeuroML/CElegans/generatedNeuroML2/SMDVL.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/SMDVL.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/CElegansNeuroML/CElegans/generatedNeuroML2/IL2L.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/IL2L.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/CElegansNeuroML/CElegans/generatedNeuroML2/ADAL.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/ADAL.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/CElegansNeuroML/CElegans/generatedNeuroML2/RIBL.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/RIBL.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/CElegansNeuroML/CElegans/generatedNeuroML2/GABA.synapse.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/GABA.synapse.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/CElegansNeuroML/CElegans/generatedNeuroML2/PDEL.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/PDEL.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/CElegansNeuroML/CElegans/generatedNeuroML2/RMFL.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/RMFL.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/CElegansNeuroML/CElegans/generatedNeuroML2/RIML.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/RIML.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/CElegansNeuroML/CElegans/generatedNeuroML2/CANL.cell.nml → /home/rohit/Desktop/Projects/C-Elegans/data/neuroml/cell_library/CANL.cell.nml
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/CElegansNeuroML/.git/description → /home/rohit/Desktop/Projects/C-Elegans/data/temp/description
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/CElegansNeuroML/.git/config → /home/rohit/Desktop/Projects/C-Elegans/data/temp/config
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/CElegansNeuroML/.git/packed-refs → /home/rohit/Desktop/Projects/C-Elegans/data/temp/packed-refs
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/CElegansNeuroML/.git/HEAD → /home/rohit/Desktop/Projects/C-Elegans/data/temp/HEAD
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/CElegansNeuroML/.git/hooks/pre-commit.sample → /home/rohit/Desktop/Projects/C-Elegans/data/temp/pre-commit.sample
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/CElegansNeuroML/.git/hooks/pre-merge-commit.sample → /home/rohit/Desktop/Projects/C-Elegans/data/temp/pre-merge-commit.sample
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/CElegansNeuroML/.git/hooks/applypatch-msg.sample → /home/rohit/Desktop/Projects/C-Elegans/data/temp/applypatch-msg.sample
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/CElegansNeuroML/.git/hooks/fsmonitor-watchman.sample → /home/rohit/Desktop/Projects/C-Elegans/data/temp/fsmonitor-watchman.sample
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/CElegansNeuroML/.git/hooks/pre-push.sample → /home/rohit/Desktop/Projects/C-Elegans/data/temp/pre-push.sample
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/CElegansNeuroML/.git/hooks/pre-receive.sample → /home/rohit/Desktop/Projects/C-Elegans/data/temp/pre-receive.sample
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/CElegansNeuroML/.git/hooks/update.sample → /home/rohit/Desktop/Projects/C-Elegans/data/temp/update.sample
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/CElegansNeuroML/.git/hooks/commit-msg.sample → /home/rohit/Desktop/Projects/C-Elegans/data/temp/commit-msg.sample
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/CElegansNeuroML/.git/hooks/prepare-commit-msg.sample → /home/rohit/Desktop/Projects/C-Elegans/data/temp/prepare-commit-msg.sample
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/CElegansNeuroML/.git/hooks/push-to-checkout.sample → /home/rohit/Desktop/Projects/C-Elegans/data/temp/push-to-checkout.sample
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/CElegansNeuroML/.git/hooks/pre-applypatch.sample → /home/rohit/Desktop/Projects/C-Elegans/data/temp/pre-applypatch.sample
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/CElegansNeuroML/.git/hooks/post-update.sample → /home/rohit/Desktop/Projects/C-Elegans/data/temp/post-update.sample
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/CElegansNeuroML/.git/hooks/pre-rebase.sample → /home/rohit/Desktop/Projects/C-Elegans/data/temp/pre-rebase.sample
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/CElegansNeuroML/.git/objects/pack/pack-afcfb4d17acfc74776c53106743b7b23a3c6f0c0.pack → /home/rohit/Desktop/Projects/C-Elegans/data/temp/pack-afcfb4d17acfc74776c53106743b7b23a3c6f0c0.pack
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/CElegansNeuroML/.git/objects/pack/pack-afcfb4d17acfc74776c53106743b7b23a3c6f0c0.idx → /home/rohit/Desktop/Projects/C-Elegans/data/temp/pack-afcfb4d17acfc74776c53106743b7b23a3c6f0c0.idx
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/CElegansNeuroML/.git/logs/HEAD → /home/rohit/Desktop/Projects/C-Elegans/data/temp/HEAD
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/CElegansNeuroML/.git/logs/refs/heads/master → /home/rohit/Desktop/Projects/C-Elegans/data/temp/master
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/CElegansNeuroML/.git/logs/refs/remotes/origin/HEAD → /home/rohit/Desktop/Projects/C-Elegans/data/temp/HEAD
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/CElegansNeuroML/.git/refs/heads/master → /home/rohit/Desktop/Projects/C-Elegans/data/temp/master
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/CElegansNeuroML/.git/refs/remotes/origin/HEAD → /home/rohit/Desktop/Projects/C-Elegans/data/temp/HEAD
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/CElegansNeuroML/.git/info/exclude → /home/rohit/Desktop/Projects/C-Elegans/data/temp/exclude
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/celegans_neural_data/.gitattributes → /home/rohit/Desktop/Projects/C-Elegans/data/temp/.gitattributes
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/celegans_neural_data/datasetcard.md → /home/rohit/Desktop/Projects/C-Elegans/data/temp/datasetcard.md
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/celegans_neural_data/new_dataset_script.py → /home/rohit/Desktop/Projects/C-Elegans/data/temp/new_dataset_script.py
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/celegans_neural_data/worm_data_short.parquet → /home/rohit/Desktop/Projects/C-Elegans/data/temp/worm_data_short.parquet
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/celegans_neural_data/README.md → /home/rohit/Desktop/Projects/C-Elegans/data/temp/README.md
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/celegans_neural_data/.git/description → /home/rohit/Desktop/Projects/C-Elegans/data/temp/description
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/celegans_neural_data/.git/config → /home/rohit/Desktop/Projects/C-Elegans/data/temp/config
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/celegans_neural_data/.git/index → /home/rohit/Desktop/Projects/C-Elegans/data/temp/index
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/celegans_neural_data/.git/packed-refs → /home/rohit/Desktop/Projects/C-Elegans/data/temp/packed-refs
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/celegans_neural_data/.git/HEAD → /home/rohit/Desktop/Projects/C-Elegans/data/temp/HEAD
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/celegans_neural_data/.git/hooks/pre-commit.sample → /home/rohit/Desktop/Projects/C-Elegans/data/temp/pre-commit.sample
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/celegans_neural_data/.git/hooks/pre-merge-commit.sample → /home/rohit/Desktop/Projects/C-Elegans/data/temp/pre-merge-commit.sample
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/celegans_neural_data/.git/hooks/applypatch-msg.sample → /home/rohit/Desktop/Projects/C-Elegans/data/temp/applypatch-msg.sample
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/celegans_neural_data/.git/hooks/post-commit → /home/rohit/Desktop/Projects/C-Elegans/data/temp/post-commit
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/celegans_neural_data/.git/hooks/pre-push → /home/rohit/Desktop/Projects/C-Elegans/data/temp/pre-push
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/celegans_neural_data/.git/hooks/post-checkout → /home/rohit/Desktop/Projects/C-Elegans/data/temp/post-checkout
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/celegans_neural_data/.git/hooks/fsmonitor-watchman.sample → /home/rohit/Desktop/Projects/C-Elegans/data/temp/fsmonitor-watchman.sample
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/celegans_neural_data/.git/hooks/pre-push.sample → /home/rohit/Desktop/Projects/C-Elegans/data/temp/pre-push.sample
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/celegans_neural_data/.git/hooks/pre-receive.sample → /home/rohit/Desktop/Projects/C-Elegans/data/temp/pre-receive.sample
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/celegans_neural_data/.git/hooks/update.sample → /home/rohit/Desktop/Projects/C-Elegans/data/temp/update.sample
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/celegans_neural_data/.git/hooks/commit-msg.sample → /home/rohit/Desktop/Projects/C-Elegans/data/temp/commit-msg.sample
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/celegans_neural_data/.git/hooks/prepare-commit-msg.sample → /home/rohit/Desktop/Projects/C-Elegans/data/temp/prepare-commit-msg.sample
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/celegans_neural_data/.git/hooks/push-to-checkout.sample → /home/rohit/Desktop/Projects/C-Elegans/data/temp/push-to-checkout.sample
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/celegans_neural_data/.git/hooks/pre-applypatch.sample → /home/rohit/Desktop/Projects/C-Elegans/data/temp/pre-applypatch.sample
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/celegans_neural_data/.git/hooks/post-update.sample → /home/rohit/Desktop/Projects/C-Elegans/data/temp/post-update.sample
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/celegans_neural_data/.git/hooks/pre-rebase.sample → /home/rohit/Desktop/Projects/C-Elegans/data/temp/pre-rebase.sample
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/celegans_neural_data/.git/hooks/post-merge → /home/rohit/Desktop/Projects/C-Elegans/data/temp/post-merge
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/celegans_neural_data/.git/lfs/objects/17/70/17701963149851d37d40955096de181d8c5378c256fe4ede93864380f9363ddc → /home/rohit/Desktop/Projects/C-Elegans/data/temp/17701963149851d37d40955096de181d8c5378c256fe4ede93864380f9363ddc
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/celegans_neural_data/.git/objects/pack/pack-c5ed4fad7f28b7df166ef78029ca843ed2558df2.pack → /home/rohit/Desktop/Projects/C-Elegans/data/temp/pack-c5ed4fad7f28b7df166ef78029ca843ed2558df2.pack
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/celegans_neural_data/.git/objects/pack/pack-c5ed4fad7f28b7df166ef78029ca843ed2558df2.idx → /home/rohit/Desktop/Projects/C-Elegans/data/temp/pack-c5ed4fad7f28b7df166ef78029ca843ed2558df2.idx
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/celegans_neural_data/.git/logs/HEAD → /home/rohit/Desktop/Projects/C-Elegans/data/temp/HEAD
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/celegans_neural_data/.git/logs/refs/heads/main → /home/rohit/Desktop/Projects/C-Elegans/data/temp/main
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/celegans_neural_data/.git/logs/refs/remotes/origin/HEAD → /home/rohit/Desktop/Projects/C-Elegans/data/temp/HEAD
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/celegans_neural_data/.git/refs/heads/main → /home/rohit/Desktop/Projects/C-Elegans/data/temp/main
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/celegans_neural_data/.git/refs/remotes/origin/HEAD → /home/rohit/Desktop/Projects/C-Elegans/data/temp/HEAD
# ✅ Moved: /home/rohit/Desktop/Projects/C-Elegans/celegans_neural_data/.git/info/exclude → /home/rohit/Desktop/Projects/C-Elegans/data/temp/exclude

# %%
import os
import pandas as pd

# Load manifest
manifest_path = "/home/rohit/Desktop/Projects/C-Elegans/utils/data_restructure_manifest.csv"
manifest = pd.read_csv(manifest_path)

# Verify each canonical path
manifest['file_exists'] = manifest['canonical_path'].apply(lambda x: os.path.exists(x))

# Report missing files
missing = manifest[~manifest['file_exists']]
if not missing.empty:
    print("⚠️ Missing files:")
    print(missing[['original_path', 'canonical_path']])
else:
    print("✅ All files successfully moved and verified.")

# Save clean manifest
clean_manifest_path = "/home/rohit/Desktop/Projects/C-Elegans/utils/data_restructure_manifest_verified.csv"
manifest.to_csv(clean_manifest_path, index=False)

print(f"📦 Verified manifest saved to: {clean_manifest_path}")
# Out:
# ✅ All files successfully moved and verified.
# 📦 Verified manifest saved to: /home/rohit/Desktop/Projects/C-Elegans/utils/data_restructure_manifest_verified.csv

# %%
import os
import pandas as pd

# Define base directory
base_dir = "/home/rohit/Desktop/Projects/C-Elegans/data"

# Recursively scan for files
file_records = []
for root, dirs, files in os.walk(base_dir):
    for name in files:
        full_path = os.path.join(root, name)
        rel_path = os.path.relpath(full_path, base_dir)
        size_kb = round(os.path.getsize(full_path) / 1024, 2)
        ext = os.path.splitext(name)[1].lower()
        file_records.append({
            "filename": name,
            "relative_path": rel_path,
            "full_path": full_path,
            "extension": ext,
            "size_kb": size_kb
        })

# Create DataFrame
file_df = pd.DataFrame(file_records)

# Save to CSV
scan_output_path = "/home/rohit/Desktop/Projects/C-Elegans/utils/postmove_directory_inventory.csv"
file_df.to_csv(scan_output_path, index=False)

# Preview
print("✅ Directory re-scan complete.")
print(f"📦 Inventory saved to: {scan_output_path}")
print("\n📂 Top 10 entries:")
print(file_df.head(10))
# Out:
# ✅ Directory re-scan complete.
# 📦 Inventory saved to: /home/rohit/Desktop/Projects/C-Elegans/utils/postmove_directory_inventory.csv
#
# 📂 Top 10 entries:
#                    filename                  relative_path  \
# 0     .test.pharyngealC.mep     temp/.test.pharyngealC.mep
# 1             ASJR.java.xml             temp/ASJR.java.xml
# 2            URXL.morph.xml            temp/URXL.morph.xml
# 3      LEMS_c302_A_Syns.xml      temp/LEMS_c302_A_Syns.xml
# 4           SMDDR.morph.xml           temp/SMDDR.morph.xml
# 5             ADFR.java.xml             temp/ADFR.java.xml
# 6  .test.pharC1.jnmlnrn.omt  temp/.test.pharC1.jnmlnrn.omt
# 7               M4.java.xml               temp/M4.java.xml
# 8   Serotonin_Glutamate.xml   temp/Serotonin_Glutamate.xml
# 9            VA10.morph.xml            temp/VA10.morph.xml
#
#                                            full_path extension  size_kb
# 0  /home/rohit/Desktop/Projects/C-Elegans/data/te...      .mep     0.17
# 1  /home/rohit/Desktop/Projects/C-Elegans/data/te...      .xml    31.10
# 2  /home/rohit/Desktop/Projects/C-Elegans/data/te...      .xml     5.99
# 3  /home/rohit/Desktop/Projects/C-Elegans/data/te...      .xml     5.06
# 4  /home/rohit/Desktop/Projects/C-Elegans/data/te...      .xml     9.74
# 5  /home/rohit/Desktop/Projects/C-Elegans/data/te...      .xml    29.24
# 6  /home/rohit/Desktop/Projects/C-Elegans/data/te...      .omt     0.51
# 7  /home/rohit/Desktop/Projects/C-Elegans/data/te...      .xml    42.21
# 8  /home/rohit/Desktop/Projects/C-Elegans/data/te...      .xml     1.16
# 9  /home/rohit/Desktop/Projects/C-Elegans/data/te...      .xml     4.15

# %%
import pandas as pd
import os
import json

# Load inventory
inventory_path = "/home/rohit/Desktop/Projects/C-Elegans/utils/postmove_directory_inventory.csv"
df = pd.read_csv(inventory_path)

# Filter for data files
data_files = df[df['extension'].isin(['.csv', '.xls', '.xlsx'])]

# Extract column name previews
column_schema = {}

for _, row in data_files.iterrows():
    path = row['full_path']
    ext = row['extension']
    try:
        if ext == ".csv":
            cols = pd.read_csv(path, nrows=1).columns.tolist()
        elif ext in [".xls", ".xlsx"]:
            cols = pd.read_excel(path, nrows=1).columns.tolist()
        else:
            continue
        column_schema[row['relative_path']] = cols
    except Exception as e:
        column_schema[row['relative_path']] = f"⚠️ Error reading file: {str(e)}"

# Save to JSON
output_path = "/home/rohit/Desktop/Projects/C-Elegans/utils/canonical_column_names.json"
with open(output_path, "w") as f:
    json.dump(column_schema, f, indent=2)

print(f"✅ Canonical column schema saved to:\n{output_path}")
# Out:
# ✅ Canonical column schema saved to:
# /home/rohit/Desktop/Projects/C-Elegans/utils/canonical_column_names.json

# %%
import pandas as pd
import os

# === Paths ===
base_dir = "/home/rohit/Desktop/Projects/C-Elegans"
utils_dir = os.path.join(base_dir, "utils")

pre_move_path = os.path.join("structured_data_inventory.csv")
post_move_path = os.path.join(utils_dir, "postmove_directory_inventory.csv")
report_path = os.path.join(utils_dir, "data_validation_report.csv")

# === Load inventories ===
pre = pd.read_csv(pre_move_path)
post = pd.read_csv(post_move_path)

# === Normalize for comparison ===
pre["basename"] = pre["full_path"].apply(os.path.basename)
post["basename"] = post["Path"].apply(os.path.basename)
pre["size_kb"] = pre["size_kb"].round(2)
post["Size (KB)"] = post["Size (KB)"].round(2)

# === Match on basename and size ===
pre["status"] = pre.apply(lambda row: (
    "✅ Moved"
    if ((post["basename"] == row["basename"]) & 
        (post["Size (KB)"] == row["size_kb"])).any()
    else "❌ Missing"
), axis=1)

# === Detect extra (new) files ===
extra = post[~post["basename"].isin(pre["basename"])].copy()
extra["status"] = "🆕 New (not in original inventory)"

# === Combine report ===
report = pd.concat([
    pre[["basename", "size_kb", "status"]],
    extra[["basename", "Size (KB)", "status"]].rename(columns={"Size (KB)": "size_kb"})
], ignore_index=True)

# === Save and show ===
report.to_csv(report_path, index=False)
print(f"📦 Validation report saved to:\n{report_path}")
report.head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Path'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 18
#      16 # === Normalize for comparison ===
#      17 pre["basename"] = pre["full_path"].apply(os.path.basename)
# ---> 18 post["basename"] = post["Path"].apply(os.path.basename)
#      19 pre["size_kb"] = pre["size_kb"].round(2)
#      20 post["Size (KB)"] = post["Size (KB)"].round(2)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:4107, in DataFrame.__getitem__(self, key)
#    4105 if self.columns.nlevels > 1:
#    4106     return self._getitem_multilevel(key)
# -> 4107 indexer = self.columns.get_loc(key)
#    4108 if is_integer(indexer):
#    4109     indexer = [indexer]
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'Path'

# %%
import pandas as pd

postmove_path = "/home/rohit/Desktop/Projects/C-Elegans/utils/postmove_directory_inventory.csv"
post = pd.read_csv(postmove_path)

print("🧾 Columns in post-move inventory:")
print(post.columns.tolist())
# Out:
# 🧾 Columns in post-move inventory:
# ['filename', 'relative_path', 'full_path', 'extension', 'size_kb']

# %%
import pandas as pd
import os

# === Paths ===
base_dir = "/home/rohit/Desktop/Projects/C-Elegans"
utils_dir = os.path.join(base_dir, "utils")

pre_move_path = "structured_data_inventory.csv"
post_move_path = os.path.join(utils_dir, "postmove_directory_inventory.csv")
report_path = os.path.join(utils_dir, "data_validation_report.csv")

# === Load inventories ===
pre = pd.read_csv(pre_move_path)
post = pd.read_csv(post_move_path)

# === Normalize for comparison ===
pre["basename"] = pre["full_path"].apply(os.path.basename)
post["basename"] = post["full_path"].apply(os.path.basename)
pre["size_kb"] = pre["size_kb"].round(2)
post["size_kb"] = post["size_kb"].round(2)

# === Match on basename and size ===
pre["status"] = pre.apply(lambda row: (
    "✅ Moved"
    if ((post["basename"] == row["basename"]) & 
        (post["size_kb"] == row["size_kb"])).any()
    else "❌ Missing"
), axis=1)

# === Detect extra (new) files ===
extra = post[~post["basename"].isin(pre["basename"])].copy()
extra["status"] = "🆕 New (not in original inventory)"
extra = extra.rename(columns={"size_kb": "size_kb"})  # For uniformity

# === Combine report ===
report = pd.concat([
    pre[["basename", "size_kb", "status"]],
    extra[["basename", "size_kb", "status"]]
], ignore_index=True)

# === Save report ===
report.to_csv(report_path, index=False)
print(f"✅ Data validation report saved:\n{report_path}")

# Preview first few mismatches
report[report["status"] != "✅ Moved"].head(10)
# Out:
# ✅ Data validation report saved:
# /home/rohit/Desktop/Projects/C-Elegans/utils/data_validation_report.csv
#                       basename  size_kb     status
# 2               celegans.ipynb  2766.29  ❌ Missing
# 12            data_catalog.yml     0.74  ❌ Missing
# 14               .openworm.yml     0.56  ❌ Missing
# 16                  .gitignore     4.29  ❌ Missing
# 18                   README.md    15.48  ❌ Missing
# 19       .test.pharyngealC.mep     0.12  ❌ Missing
# 20        LEMS_c302_A_Syns.xml     5.24  ❌ Missing
# 22        c302_C1_Full.net.nml  1516.94  ❌ Missing
# 23   c302_B_Oscillator.net.nml    29.42  ❌ Missing
# 24  LEMS_c302_C_Oscillator.xml    10.15  ❌ Missing

# %%
import os
import shutil
import pandas as pd

base_path = "/home/rohit/Desktop/Projects/C-Elegans"
missing_files = [
    "LEMS_c302_A_Syns.xml",
    "LEMS_c302_C_Oscillator.xml",
    "c302_B_Oscillator.net.nml",
    "c302_C1_Full.net.nml"
]
nml_target_dir = os.path.join(base_path, "data", "nml")
os.makedirs(nml_target_dir, exist_ok=True)

# Step 1: Move files
moved = []
for fname in missing_files:
    for root, _, files in os.walk(base_path):
        if fname in files:
            src = os.path.join(root, fname)
            dst = os.path.join(nml_target_dir, fname)
            shutil.move(src, dst)
            moved.append((fname, src, dst))
            break

# Step 2: Load and update manifest
manifest_path = os.path.join(base_path, "utils", "data_restructure_manifest_verified.csv")
manifest = pd.read_csv(manifest_path)

# New rows for moved files
new_rows = pd.DataFrame([{
    "basename": fname,
    "original_path": src,
    "canonical_path": dst,
    "category": "nml",
    "status": "✅ Moved"
} for fname, src, dst in moved])

# Concatenate and save
manifest = pd.concat([manifest, new_rows], ignore_index=True)
manifest.to_csv(manifest_path, index=False)

# Final print
print("✅ Moved the following NML/LEMS files to /data/nml/:")
for f in moved:
    print(f" - {f[0]}")

print(f"\n📦 Updated manifest saved to:\n{manifest_path}")
# Out:
# ✅ Moved the following NML/LEMS files to /data/nml/:
#  - LEMS_c302_A_Syns.xml
#  - LEMS_c302_C_Oscillator.xml
#  - c302_B_Oscillator.net.nml
#  - c302_C1_Full.net.nml
#
# 📦 Updated manifest saved to:
# /home/rohit/Desktop/Projects/C-Elegans/utils/data_restructure_manifest_verified.csv

# %%
import os
import pandas as pd

# === Paths ===
base_path = "/home/rohit/Desktop/Projects/C-Elegans"
manifest_path = os.path.join(base_path, "utils", "data_restructure_manifest_verified.csv")

# === Load manifest ===
manifest = pd.read_csv(manifest_path)
manifest["basename"] = manifest["canonical_path"].apply(os.path.basename)

# === Recursively walk the directory ===
file_records = []
for root, _, files in os.walk(base_path):
    for f in files:
        full_path = os.path.join(root, f)
        rel_path = os.path.relpath(full_path, base_path)
        file_records.append({
            "basename": f,
            "relative_path": rel_path,
            "full_path": full_path,
            "size_kb": os.path.getsize(full_path) / 1024
        })

scanned_df = pd.DataFrame(file_records)

# === Merge with manifest ===
merged = pd.merge(manifest, scanned_df, on="basename", how="outer", indicator=True)

# === Tag result ===
merged["status"] = merged["_merge"].map({
    "both": "✅ Verified",
    "left_only": "❌ Missing in Filesystem",
    "right_only": "🆕 Not in Manifest"
})

# === Export results ===
output_path = os.path.join(base_path, "utils", "final_verification_report.csv")
merged.to_csv(output_path, index=False)

# === Summary ===
summary = merged["status"].value_counts().to_dict()
print("✅ Post-Move Scan Complete:")
print(f" - Verified: {summary.get('✅ Verified', 0)}")
print(f" - Missing: {summary.get('❌ Missing in Filesystem', 0)}")
print(f" - Unexpected: {summary.get('🆕 Not in Manifest', 0)}")
print(f"\n📄 Report saved to:\n{output_path}")
# Out:
# ✅ Post-Move Scan Complete:
#  - Verified: 3226
#  - Missing: 0
#  - Unexpected: 6
#
# 📄 Report saved to:
# /home/rohit/Desktop/Projects/C-Elegans/utils/final_verification_report.csv
